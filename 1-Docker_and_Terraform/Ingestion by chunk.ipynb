# %%
import pandas as pd

# %%
import time
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError
import logging

# %%
file_path = 'dataset/yellow_tripdata/yellow_tripdata_2021-01.csv'
batch_size = 10000

# %%
df_iter = pd.read_csv('dataset/yellow_tripdata/yellow_tripdata_2021-01.csv', chunksize=batch_size)

# %%
df_iter

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(test_dt,name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TEXT,
# 	tpep_dropoff_datetime TEXT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
string_columns = ["VendorID","RatecodeID","DOLocationID","payment_type"]

# Function to detect and convert datetime columns
def convert_datatype_columns(df):
    for col in df.columns:
        if df[col].dtype == 'object':  # Check if the column is of object type (likely strings)
            try:
                df[col] = pd.to_datetime(df[col])
                logging.info(f"Converted column '{col}' to datetime.")
            except (ValueError, TypeError):
                logging.info(f"Column '{col}' is not a datetime column.")
        if col in string_columns:
            df[col] = df[col].astype('object')
    return df

# %%
# Function to process and insert a chunk
def process_and_insert_chunk(df):
    try:
        df = convert_datatype_columns(df)  # Convert datetime columns dynamically
        df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append", index=False)
        return True
    except SQLAlchemyError as e:
        logging.error(f"Error inserting chunk: {e}")
        return False

# %%
# Main ingestion loop
total_chunks = 0
successful_chunks = 0

for df in df_iter:
    total_chunks += 1
    t_start = time.time()
    
    if process_and_insert_chunk(df):
        successful_chunks += 1
        t_end = time.time()
        logging.info(f"Inserted chunk {total_chunks}, took {t_end - t_start:.3f} seconds")
    else:
        logging.warning(f"Failed to insert chunk {total_chunks}")

logging.info(f"Ingestion completed. Total chunks: {total_chunks}, Successful chunks: {successful_chunks}")

print("done")
# Out:
# 2025-02-01 18:52:58,707 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:52:58,712 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:52:58,717 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:00,315 - INFO - Inserted chunk 1, took 1.614 seconds
# 2025-02-01 18:53:00,347 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:00,352 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:00,355 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:01,717 - INFO - Inserted chunk 2, took 1.378 seconds
# 2025-02-01 18:53:01,748 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:01,753 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:01,755 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:03,055 - INFO - Inserted chunk 3, took 1.314 seconds
# 2025-02-01 18:53:03,087 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:03,093 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:03,095 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:04,462 - INFO - Inserted chunk 4, took 1.382 seconds
# 2025-02-01 18:53:04,497 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:04,503 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:04,505 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:06,002 - INFO - Inserted chunk 5, took 1.511 seconds
# 2025-02-01 18:53:06,030 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:06,035 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:06,037 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:07,345 - INFO - Inserted chunk 6, took 1.320 seconds
# 2025-02-01 18:53:07,371 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:07,376 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:07,379 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:08,676 - INFO - Inserted chunk 7, took 1.309 seconds
# 2025-02-01 18:53:08,702 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:08,706 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:08,709 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:09,986 - INFO - Inserted chunk 8, took 1.289 seconds
# 2025-02-01 18:53:10,016 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:10,022 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:10,024 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:11,225 - INFO - Inserted chunk 9, took 1.215 seconds
# 2025-02-01 18:53:11,253 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:11,258 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:11,259 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:12,573 - INFO - Inserted chunk 10, took 1.325 seconds
# 2025-02-01 18:53:12,604 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:12,609 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:12,612 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:13,915 - INFO - Inserted chunk 11, took 1.317 seconds
# 2025-02-01 18:53:13,943 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:13,949 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:13,951 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:15,292 - INFO - Inserted chunk 12, took 1.353 seconds
# 2025-02-01 18:53:15,323 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:15,330 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:15,332 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:16,653 - INFO - Inserted chunk 13, took 1.336 seconds
# 2025-02-01 18:53:16,687 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:16,692 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:16,694 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:17,835 - INFO - Inserted chunk 14, took 1.155 seconds
# 2025-02-01 18:53:17,865 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:17,869 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:17,872 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:19,236 - INFO - Inserted chunk 15, took 1.376 seconds
# 2025-02-01 18:53:19,265 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:19,270 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:19,273 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:20,690 - INFO - Inserted chunk 16, took 1.429 seconds
# 2025-02-01 18:53:20,719 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:20,726 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:20,728 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:22,016 - INFO - Inserted chunk 17, took 1.302 seconds
# 2025-02-01 18:53:22,044 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:22,051 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:22,053 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:23,423 - INFO - Inserted chunk 18, took 1.385 seconds
# 2025-02-01 18:53:23,455 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:23,460 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:23,463 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:24,644 - INFO - Inserted chunk 19, took 1.195 seconds
# 2025-02-01 18:53:24,674 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:24,680 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:24,682 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:26,008 - INFO - Inserted chunk 20, took 1.338 seconds
# 2025-02-01 18:53:26,035 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:26,040 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:26,042 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:27,345 - INFO - Inserted chunk 21, took 1.313 seconds
# 2025-02-01 18:53:27,374 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:27,378 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:27,381 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:28,785 - INFO - Inserted chunk 22, took 1.415 seconds
# 2025-02-01 18:53:28,813 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:28,817 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:28,820 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:30,118 - INFO - Inserted chunk 23, took 1.309 seconds
# 2025-02-01 18:53:30,142 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:30,146 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:30,149 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:31,426 - INFO - Inserted chunk 24, took 1.287 seconds
# 2025-02-01 18:53:31,452 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:31,457 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:31,459 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:32,682 - INFO - Inserted chunk 25, took 1.234 seconds
# 2025-02-01 18:53:32,715 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:32,720 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:32,722 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:34,105 - INFO - Inserted chunk 26, took 1.396 seconds
# 2025-02-01 18:53:34,137 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:34,143 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:34,145 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:35,621 - INFO - Inserted chunk 27, took 1.489 seconds
# 2025-02-01 18:53:35,649 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:35,653 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:35,655 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:36,951 - INFO - Inserted chunk 28, took 1.307 seconds
# 2025-02-01 18:53:36,977 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:36,984 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:36,986 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:38,171 - INFO - Inserted chunk 29, took 1.198 seconds
# 2025-02-01 18:53:38,205 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:38,210 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:38,212 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:39,493 - INFO - Inserted chunk 30, took 1.295 seconds
# 2025-02-01 18:53:39,527 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:39,534 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:39,537 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:40,766 - INFO - Inserted chunk 31, took 1.244 seconds
# 2025-02-01 18:53:40,798 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:40,803 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:40,806 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:42,079 - INFO - Inserted chunk 32, took 1.287 seconds
# 2025-02-01 18:53:42,111 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:42,116 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:42,118 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:43,320 - INFO - Inserted chunk 33, took 1.215 seconds
# 2025-02-01 18:53:43,350 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:43,354 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:43,356 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:44,369 - INFO - Inserted chunk 34, took 1.023 seconds
# 2025-02-01 18:53:44,403 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:44,408 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:44,410 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:45,728 - INFO - Inserted chunk 35, took 1.331 seconds
# 2025-02-01 18:53:45,766 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:45,773 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:45,775 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:47,021 - INFO - Inserted chunk 36, took 1.260 seconds
# 2025-02-01 18:53:47,051 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:47,056 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:47,057 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:48,541 - INFO - Inserted chunk 37, took 1.495 seconds
# 2025-02-01 18:53:48,574 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:48,581 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:48,583 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:49,817 - INFO - Inserted chunk 38, took 1.249 seconds
# 2025-02-01 18:53:49,846 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:49,850 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:49,852 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:51,119 - INFO - Inserted chunk 39, took 1.278 seconds
# 2025-02-01 18:53:51,147 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:51,152 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:51,155 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:52,413 - INFO - Inserted chunk 40, took 1.270 seconds
# 2025-02-01 18:53:52,446 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:52,452 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:52,454 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:53,782 - INFO - Inserted chunk 41, took 1.342 seconds
# 2025-02-01 18:53:53,809 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:53,813 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:53,815 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:55,106 - INFO - Inserted chunk 42, took 1.303 seconds
# 2025-02-01 18:53:55,133 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:55,138 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:55,140 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:56,432 - INFO - Inserted chunk 43, took 1.303 seconds
# 2025-02-01 18:53:56,466 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:56,470 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:56,471 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:57,613 - INFO - Inserted chunk 44, took 1.152 seconds
# 2025-02-01 18:53:57,641 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:57,645 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:57,647 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:53:58,848 - INFO - Inserted chunk 45, took 1.211 seconds
# 2025-02-01 18:53:58,875 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:53:58,880 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:53:58,883 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:00,125 - INFO - Inserted chunk 46, took 1.255 seconds
# 2025-02-01 18:54:00,155 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:00,161 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:00,163 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:01,412 - INFO - Inserted chunk 47, took 1.261 seconds
# 2025-02-01 18:54:01,439 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:01,446 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:01,448 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:02,812 - INFO - Inserted chunk 48, took 1.377 seconds
# 2025-02-01 18:54:02,841 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:02,846 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:02,848 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:04,016 - INFO - Inserted chunk 49, took 1.180 seconds
# 2025-02-01 18:54:04,045 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:04,050 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:04,052 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:05,294 - INFO - Inserted chunk 50, took 1.253 seconds
# 2025-02-01 18:54:05,327 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:05,333 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:05,335 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:06,596 - INFO - Inserted chunk 51, took 1.276 seconds
# 2025-02-01 18:54:06,627 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:06,632 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:06,635 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:08,128 - INFO - Inserted chunk 52, took 1.505 seconds
# 2025-02-01 18:54:08,155 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:08,160 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:08,161 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:09,660 - INFO - Inserted chunk 53, took 1.509 seconds
# 2025-02-01 18:54:09,690 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:09,695 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:09,697 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:11,028 - INFO - Inserted chunk 54, took 1.342 seconds
# 2025-02-01 18:54:11,055 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:11,060 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:11,062 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:12,283 - INFO - Inserted chunk 55, took 1.232 seconds
# 2025-02-01 18:54:12,314 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:12,320 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:12,322 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:13,650 - INFO - Inserted chunk 56, took 1.341 seconds
# 2025-02-01 18:54:13,684 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:13,691 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:13,693 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:14,939 - INFO - Inserted chunk 57, took 1.261 seconds
# 2025-02-01 18:54:14,977 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:14,981 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:14,984 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:16,507 - INFO - Inserted chunk 58, took 1.536 seconds
# 2025-02-01 18:54:16,538 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:16,542 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:16,544 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:17,863 - INFO - Inserted chunk 59, took 1.329 seconds
# 2025-02-01 18:54:17,894 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:17,900 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:17,902 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:19,234 - INFO - Inserted chunk 60, took 1.347 seconds
# 2025-02-01 18:54:19,260 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:19,267 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:19,269 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:20,553 - INFO - Inserted chunk 61, took 1.297 seconds
# 2025-02-01 18:54:20,583 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:20,590 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:20,592 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:21,960 - INFO - Inserted chunk 62, took 1.382 seconds
# 2025-02-01 18:54:21,988 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:21,994 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:21,996 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:23,290 - INFO - Inserted chunk 63, took 1.308 seconds
# 2025-02-01 18:54:23,315 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:23,320 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:23,322 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:24,728 - INFO - Inserted chunk 64, took 1.418 seconds
# 2025-02-01 18:54:24,769 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:24,778 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:24,782 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:26,178 - INFO - Inserted chunk 65, took 1.419 seconds
# 2025-02-01 18:54:26,219 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:26,225 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:26,227 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:27,649 - INFO - Inserted chunk 66, took 1.437 seconds
# 2025-02-01 18:54:27,694 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:27,715 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:27,718 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:29,072 - INFO - Inserted chunk 67, took 1.387 seconds
# 2025-02-01 18:54:29,101 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:29,106 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:29,107 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:30,499 - INFO - Inserted chunk 68, took 1.402 seconds
# 2025-02-01 18:54:30,527 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:30,533 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:30,536 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:32,033 - INFO - Inserted chunk 69, took 1.512 seconds
# 2025-02-01 18:54:32,064 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:32,068 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:32,070 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:33,286 - INFO - Inserted chunk 70, took 1.229 seconds
# 2025-02-01 18:54:33,316 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:33,320 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:33,322 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:34,621 - INFO - Inserted chunk 71, took 1.311 seconds
# 2025-02-01 18:54:34,652 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:34,656 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:34,659 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:35,979 - INFO - Inserted chunk 72, took 1.333 seconds
# 2025-02-01 18:54:36,010 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:36,016 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:36,017 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:37,218 - INFO - Inserted chunk 73, took 1.214 seconds
# 2025-02-01 18:54:37,244 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:37,248 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:37,250 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:38,554 - INFO - Inserted chunk 74, took 1.315 seconds
# 2025-02-01 18:54:38,579 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:38,585 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:38,587 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:39,915 - INFO - Inserted chunk 75, took 1.340 seconds
# 2025-02-01 18:54:39,947 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:39,953 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:39,955 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:41,318 - INFO - Inserted chunk 76, took 1.378 seconds
# 2025-02-01 18:54:41,345 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:41,349 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:54:41,351 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:54:42,600 - INFO - Inserted chunk 77, took 1.261 seconds
# 2025-02-01 18:54:42,629 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:54:42,633 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# ...
# 2025-02-01 18:55:15,298 - INFO - Inserted chunk 102, took 1.322 seconds
# 2025-02-01 18:55:15,327 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:15,333 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:15,337 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:16,519 - INFO - Inserted chunk 103, took 1.196 seconds
# 2025-02-01 18:55:16,556 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:16,564 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:16,566 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:18,011 - INFO - Inserted chunk 104, took 1.460 seconds
# 2025-02-01 18:55:18,043 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:18,049 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:18,052 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:19,291 - INFO - Inserted chunk 105, took 1.254 seconds
# 2025-02-01 18:55:19,319 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:19,324 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:19,327 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:20,585 - INFO - Inserted chunk 106, took 1.270 seconds
# 2025-02-01 18:55:20,616 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:20,621 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:20,623 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:21,928 - INFO - Inserted chunk 107, took 1.317 seconds
# 2025-02-01 18:55:21,960 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:21,967 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:21,969 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:23,187 - INFO - Inserted chunk 108, took 1.230 seconds
# 2025-02-01 18:55:23,213 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:23,218 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:23,220 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:24,441 - INFO - Inserted chunk 109, took 1.232 seconds
# 2025-02-01 18:55:24,472 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:24,479 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:24,481 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:25,970 - INFO - Inserted chunk 110, took 1.502 seconds
# 2025-02-01 18:55:26,012 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:26,017 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:26,019 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:27,148 - INFO - Inserted chunk 111, took 1.141 seconds
# 2025-02-01 18:55:27,176 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:27,181 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:27,183 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:28,385 - INFO - Inserted chunk 112, took 1.216 seconds
# 2025-02-01 18:55:28,413 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:28,418 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:28,420 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:29,584 - INFO - Inserted chunk 113, took 1.176 seconds
# 2025-02-01 18:55:29,612 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:29,616 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:29,618 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:30,712 - INFO - Inserted chunk 114, took 1.104 seconds
# 2025-02-01 18:55:30,747 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:30,753 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:30,755 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:32,166 - INFO - Inserted chunk 115, took 1.426 seconds
# 2025-02-01 18:55:32,203 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:32,211 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:32,213 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:33,616 - INFO - Inserted chunk 116, took 1.420 seconds
# 2025-02-01 18:55:33,648 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:33,654 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:33,656 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:34,912 - INFO - Inserted chunk 117, took 1.269 seconds
# 2025-02-01 18:55:34,945 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:34,951 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:34,953 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:36,246 - INFO - Inserted chunk 118, took 1.307 seconds
# 2025-02-01 18:55:36,280 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:36,285 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:36,287 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:37,526 - INFO - Inserted chunk 119, took 1.253 seconds
# 2025-02-01 18:55:37,563 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:37,568 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:37,571 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:38,895 - INFO - Inserted chunk 120, took 1.339 seconds
# 2025-02-01 18:55:38,926 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:38,931 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:38,934 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:40,238 - INFO - Inserted chunk 121, took 1.319 seconds
# 2025-02-01 18:55:40,272 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:40,276 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:40,278 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:41,513 - INFO - Inserted chunk 122, took 1.249 seconds
# 2025-02-01 18:55:41,540 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:41,545 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:41,548 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:42,882 - INFO - Inserted chunk 123, took 1.346 seconds
# 2025-02-01 18:55:42,911 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:42,917 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# C:\Users\azaid\AppData\Local\Temp\ipykernel_35872\3916150648.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# 2025-02-01 18:55:42,920 - INFO - Column 'store_and_fwd_flag' is not a datetime column.
# 2025-02-01 18:55:43,774 - INFO - Inserted chunk 124, took 0.869 seconds
# 2025-02-01 18:55:43,804 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:43,809 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:44,765 - INFO - Inserted chunk 125, took 0.965 seconds
# 2025-02-01 18:55:44,793 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:44,799 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:45,822 - INFO - Inserted chunk 126, took 1.033 seconds
# 2025-02-01 18:55:45,850 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:45,856 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:47,160 - INFO - Inserted chunk 127, took 1.315 seconds
# 2025-02-01 18:55:47,189 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:47,194 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:48,156 - INFO - Inserted chunk 128, took 0.974 seconds
# 2025-02-01 18:55:48,184 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:48,188 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:49,061 - INFO - Inserted chunk 129, took 0.881 seconds
# 2025-02-01 18:55:49,091 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:49,095 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:50,033 - INFO - Inserted chunk 130, took 0.947 seconds
# 2025-02-01 18:55:50,063 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:50,071 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:51,005 - INFO - Inserted chunk 131, took 0.948 seconds
# 2025-02-01 18:55:51,038 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:51,043 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:52,151 - INFO - Inserted chunk 132, took 1.120 seconds
# 2025-02-01 18:55:52,183 - INFO - Converted column 'tpep_pickup_datetime' to datetime.
# 2025-02-01 18:55:52,189 - INFO - Converted column 'tpep_dropoff_datetime' to datetime.
# 2025-02-01 18:55:53,342 - INFO - Inserted chunk 133, took 1.165 seconds
# 2025-02-01 18:55:53,343 - INFO - Ingestion completed. Total chunks: 133, Successful chunks: 133
# done
